# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    #plt.axis('equal')
    plt.axis('square')
    #plt.xlim(plt.xlim())
    #plt.ylim(plt.ylim())
    #these commented lines don't make any difference.
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Get the data from UCI dataset
URL = 'https://archive.ics.uci.edu/ml/machine-learning-databases/00242/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URL)
df = df.sample(frac=1).reset_index(drop=True)
#sample: used to select rows randomly frac=1 means select all
#reset_index: drop=True, it drops the index in pandas and create new one from 0 to onward.

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()
#describe: show mean, std, percentiles..
#print(train_stats)

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
#print(train_stats)

train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train.columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 920us/sample - loss: 246.2753 - y1_output_loss: 114.8315 - y2_output_loss: 129.0767 - y1_output_root_mean_squared_error: 10.7681 - y2_output_root_mean_squared_error: 11.4159 - val_loss: 49.4020 - val_y1_output_loss: 18.2935 - val_y2_output_loss: 31.7786 - val_y1_output_root_mean_squared_error: 4.1876 - val_y2_output_root_mean_squared_error: 5.6450
# Epoch 2/500
# 614/614 [==============================] - 0s 150us/sample - loss: 32.3009 - y1_output_loss: 12.5899 - y2_output_loss: 19.7095 - y1_output_root_mean_squared_error: 3.5541 - y2_output_root_mean_squared_error: 4.4350 - val_loss: 30.5005 - val_y1_output_loss: 12.5251 - val_y2_output_loss: 18.2030 - val_y1_output_root_mean_squared_error: 3.4679 - val_y2_output_root_mean_squared_error: 4.2981
# Epoch 3/500
# 614/614 [==============================] - 0s 130us/sample - loss: 28.3098 - y1_output_loss: 10.3417 - y2_output_loss: 17.7756 - y1_output_root_mean_squared_error: 3.2266 - y2_output_root_mean_squared_error: 4.2307 - val_loss: 23.5575 - val_y1_output_loss: 10.8966 - val_y2_output_loss: 12.7440 - val_y1_output_root_mean_squared_error: 3.2311 - val_y2_output_root_mean_squared_error: 3.6218
# Epoch 4/500
# 614/614 [==============================] - 0s 129us/sample - loss: 22.9026 - y1_output_loss: 9.4084 - y2_output_loss: 13.8410 - y1_output_root_mean_squared_error: 3.0533 - y2_output_root_mean_squared_error: 3.6851 - val_loss: 56.7516 - val_y1_output_loss: 14.9576 - val_y2_output_loss: 41.9858 - val_y1_output_root_mean_squared_error: 3.8392 - val_y2_output_root_mean_squared_error: 6.4817
# Epoch 5/500
# 614/614 [==============================] - 0s 134us/sample - loss: 26.4429 - y1_output_loss: 10.0730 - y2_output_loss: 16.5134 - y1_output_root_mean_squared_error: 3.1646 - y2_output_root_mean_squared_error: 4.0532 - val_loss: 24.1568 - val_y1_output_loss: 10.4450 - val_y2_output_loss: 13.8584 - val_y1_output_root_mean_squared_error: 3.1526 - val_y2_output_root_mean_squared_error: 3.7707
# Epoch 6/500
# 614/614 [==============================] - 0s 130us/sample - loss: 21.8702 - y1_output_loss: 8.8092 - y2_output_loss: 12.9588 - y1_output_root_mean_squared_error: 2.9787 - y2_output_root_mean_squared_error: 3.6052 - val_loss: 20.5287 - val_y1_output_loss: 8.8537 - val_y2_output_loss: 11.8695 - val_y1_output_root_mean_squared_error: 2.9027 - val_y2_output_root_mean_squared_error: 3.4789
# Epoch 7/500
# 614/614 [==============================] - 0s 127us/sample - loss: 22.7251 - y1_output_loss: 8.6247 - y2_output_loss: 14.0371 - y1_output_root_mean_squared_error: 2.9416 - y2_output_root_mean_squared_error: 3.7513 - val_loss: 34.6608 - val_y1_output_loss: 12.3163 - val_y2_output_loss: 22.5553 - val_y1_output_root_mean_squared_error: 3.4644 - val_y2_output_root_mean_squared_error: 4.7601
# Epoch 8/500
# 614/614 [==============================] - 0s 132us/sample - loss: 23.6248 - y1_output_loss: 8.8614 - y2_output_loss: 15.0880 - y1_output_root_mean_squared_error: 2.9659 - y2_output_root_mean_squared_error: 3.8507 - val_loss: 32.2657 - val_y1_output_loss: 11.9438 - val_y2_output_loss: 20.5927 - val_y1_output_root_mean_squared_error: 3.4023 - val_y2_output_root_mean_squared_error: 4.5487
# Epoch 9/500
# 614/614 [==============================] - 0s 129us/sample - loss: 20.7974 - y1_output_loss: 7.9916 - y2_output_loss: 12.7283 - y1_output_root_mean_squared_error: 2.8226 - y2_output_root_mean_squared_error: 3.5819 - val_loss: 28.0999 - val_y1_output_loss: 12.1443 - val_y2_output_loss: 16.3932 - val_y1_output_root_mean_squared_error: 3.4165 - val_y2_output_root_mean_squared_error: 4.0531
# Epoch 10/500
# 614/614 [==============================] - 0s 136us/sample - loss: 22.4688 - y1_output_loss: 8.3845 - y2_output_loss: 14.2131 - y1_output_root_mean_squared_error: 2.8981 - y2_output_root_mean_squared_error: 3.7510 - val_loss: 30.0814 - val_y1_output_loss: 12.0423 - val_y2_output_loss: 18.7113 - val_y1_output_root_mean_squared_error: 3.3907 - val_y2_output_root_mean_squared_error: 4.3110
# Epoch 11/500
# 614/614 [==============================] - 0s 136us/sample - loss: 20.7800 - y1_output_loss: 7.7953 - y2_output_loss: 13.2803 - y1_output_root_mean_squared_error: 2.7691 - y2_output_root_mean_squared_error: 3.6211 - val_loss: 44.6486 - val_y1_output_loss: 13.9022 - val_y2_output_loss: 30.8598 - val_y1_output_root_mean_squared_error: 3.6753 - val_y2_output_root_mean_squared_error: 5.5804
# Epoch 12/500
# 614/614 [==============================] - 0s 131us/sample - loss: 20.3980 - y1_output_loss: 7.9153 - y2_output_loss: 12.8155 - y1_output_root_mean_squared_error: 2.7954 - y2_output_root_mean_squared_error: 3.5474 - val_loss: 29.7032 - val_y1_output_loss: 12.0233 - val_y2_output_loss: 17.8724 - val_y1_output_root_mean_squared_error: 3.4174 - val_y2_output_root_mean_squared_error: 4.2455
# Epoch 13/500
# 614/614 [==============================] - 0s 141us/sample - loss: 22.5370 - y1_output_loss: 8.3827 - y2_output_loss: 14.0185 - y1_output_root_mean_squared_error: 2.9055 - y2_output_root_mean_squared_error: 3.7543 - val_loss: 24.4812 - val_y1_output_loss: 8.7512 - val_y2_output_loss: 15.8261 - val_y1_output_root_mean_squared_error: 2.8927 - val_y2_output_root_mean_squared_error: 4.0142
# Epoch 14/500
# 614/614 [==============================] - 0s 130us/sample - loss: 18.4206 - y1_output_loss: 6.6868 - y2_output_loss: 11.6843 - y1_output_root_mean_squared_error: 2.5940 - y2_output_root_mean_squared_error: 3.4193 - val_loss: 20.4344 - val_y1_output_loss: 9.3326 - val_y2_output_loss: 11.0495 - val_y1_output_root_mean_squared_error: 3.0077 - val_y2_output_root_mean_squared_error: 3.3746
# Epoch 15/500
# 614/614 [==============================] - 0s 134us/sample - loss: 16.0997 - y1_output_loss: 6.2566 - y2_output_loss: 9.7666 - y1_output_root_mean_squared_error: 2.5088 - y2_output_root_mean_squared_error: 3.1314 - val_loss: 16.7073 - val_y1_output_loss: 7.7491 - val_y2_output_loss: 9.0654 - val_y1_output_root_mean_squared_error: 2.7141 - val_y2_output_root_mean_squared_error: 3.0563
# Epoch 16/500
# 614/614 [==============================] - 0s 131us/sample - loss: 18.9350 - y1_output_loss: 6.9764 - y2_output_loss: 11.8298 - y1_output_root_mean_squared_error: 2.6504 - y2_output_root_mean_squared_error: 3.4511 - val_loss: 19.1727 - val_y1_output_loss: 8.0205 - val_y2_output_loss: 11.3631 - val_y1_output_root_mean_squared_error: 2.7602 - val_y2_output_root_mean_squared_error: 3.3991
# Epoch 17/500
# 614/614 [==============================] - 0s 129us/sample - loss: 22.7922 - y1_output_loss: 8.0203 - y2_output_loss: 14.7714 - y1_output_root_mean_squared_error: 2.8409 - y2_output_root_mean_squared_error: 3.8369 - val_loss: 28.7011 - val_y1_output_loss: 9.1244 - val_y2_output_loss: 20.1572 - val_y1_output_root_mean_squared_error: 2.9481 - val_y2_output_root_mean_squared_error: 4.4733
# Epoch 18/500
# 614/614 [==============================] - 0s 129us/sample - loss: 16.0372 - y1_output_loss: 6.1648 - y2_output_loss: 10.0257 - y1_output_root_mean_squared_error: 2.4817 - y2_output_root_mean_squared_error: 3.1430 - val_loss: 22.2492 - val_y1_output_loss: 8.6865 - val_y2_output_loss: 14.1779 - val_y1_output_root_mean_squared_error: 2.8681 - val_y2_output_root_mean_squared_error: 3.7448
# Epoch 19/500
# 614/614 [==============================] - 0s 128us/sample - loss: 18.4442 - y1_output_loss: 6.8712 - y2_output_loss: 11.7714 - y1_output_root_mean_squared_error: 2.6016 - y2_output_root_mean_squared_error: 3.4170 - val_loss: 19.6685 - val_y1_output_loss: 9.1143 - val_y2_output_loss: 11.1627 - val_y1_output_root_mean_squared_error: 2.9256 - val_y2_output_root_mean_squared_error: 3.3331
# Epoch 20/500
# 614/614 [==============================] - 0s 138us/sample - loss: 15.4995 - y1_output_loss: 5.6703 - y2_output_loss: 9.7106 - y1_output_root_mean_squared_error: 2.3878 - y2_output_root_mean_squared_error: 3.1301 - val_loss: 15.5171 - val_y1_output_loss: 7.3100 - val_y2_output_loss: 8.2320 - val_y1_output_root_mean_squared_error: 2.6548 - val_y2_output_root_mean_squared_error: 2.9102
# Epoch 21/500
# 614/614 [==============================] - 0s 132us/sample - loss: 16.9667 - y1_output_loss: 6.3393 - y2_output_loss: 11.0041 - y1_output_root_mean_squared_error: 2.5009 - y2_output_root_mean_squared_error: 3.2730 - val_loss: 27.6504 - val_y1_output_loss: 8.8180 - val_y2_output_loss: 18.9297 - val_y1_output_root_mean_squared_error: 2.9504 - val_y2_output_root_mean_squared_error: 4.3526
# Epoch 22/500
# 614/614 [==============================] - 0s 134us/sample - loss: 14.7373 - y1_output_loss: 5.5857 - y2_output_loss: 9.0709 - y1_output_root_mean_squared_error: 2.3684 - y2_output_root_mean_squared_error: 3.0213 - val_loss: 14.3171 - val_y1_output_loss: 6.9112 - val_y2_output_loss: 7.4930 - val_y1_output_root_mean_squared_error: 2.5725 - val_y2_output_root_mean_squared_error: 2.7748
# Epoch 23/500
# 614/614 [==============================] - 0s 135us/sample - loss: 14.5746 - y1_output_loss: 5.8348 - y2_output_loss: 8.8062 - y1_output_root_mean_squared_error: 2.4037 - y2_output_root_mean_squared_error: 2.9659 - val_loss: 18.8863 - val_y1_output_loss: 7.1246 - val_y2_output_loss: 11.6231 - val_y1_output_root_mean_squared_error: 2.6241 - val_y2_output_root_mean_squared_error: 3.4641
# Epoch 24/500
# 614/614 [==============================] - 0s 136us/sample - loss: 13.7239 - y1_output_loss: 5.0426 - y2_output_loss: 8.6257 - y1_output_root_mean_squared_error: 2.2517 - y2_output_root_mean_squared_error: 2.9417 - val_loss: 24.0855 - val_y1_output_loss: 9.4315 - val_y2_output_loss: 15.2377 - val_y1_output_root_mean_squared_error: 3.0067 - val_y2_output_root_mean_squared_error: 3.8788
# Epoch 25/500
# 614/614 [==============================] - 0s 134us/sample - loss: 13.6658 - y1_output_loss: 4.9919 - y2_output_loss: 8.7693 - y1_output_root_mean_squared_error: 2.2269 - y2_output_root_mean_squared_error: 2.9507 - val_loss: 46.5020 - val_y1_output_loss: 15.0880 - val_y2_output_loss: 32.5990 - val_y1_output_root_mean_squared_error: 3.8161 - val_y2_output_root_mean_squared_error: 5.6515
# Epoch 26/500
# 614/614 [==============================] - 0s 134us/sample - loss: 13.9213 - y1_output_loss: 4.9900 - y2_output_loss: 9.0104 - y1_output_root_mean_squared_error: 2.2144 - y2_output_root_mean_squared_error: 3.0029 - val_loss: 22.5571 - val_y1_output_loss: 8.4296 - val_y2_output_loss: 13.9722 - val_y1_output_root_mean_squared_error: 2.8730 - val_y2_output_root_mean_squared_error: 3.7819
# Epoch 27/500
# 614/614 [==============================] - 0s 134us/sample - loss: 15.4748 - y1_output_loss: 5.1441 - y2_output_loss: 10.3033 - y1_output_root_mean_squared_error: 2.2734 - y2_output_root_mean_squared_error: 3.2104 - val_loss: 17.1441 - val_y1_output_loss: 5.6894 - val_y2_output_loss: 11.2080 - val_y1_output_root_mean_squared_error: 2.3710 - val_y2_output_root_mean_squared_error: 3.3945
# Epoch 28/500
# 614/614 [==============================] - 0s 136us/sample - loss: 12.6414 - y1_output_loss: 4.5749 - y2_output_loss: 7.9981 - y1_output_root_mean_squared_error: 2.1483 - y2_output_root_mean_squared_error: 2.8331 - val_loss: 14.4710 - val_y1_output_loss: 5.4635 - val_y2_output_loss: 9.2144 - val_y1_output_root_mean_squared_error: 2.2957 - val_y2_output_root_mean_squared_error: 3.0333
# Epoch 29/500
# 614/614 [==============================] - 0s 135us/sample - loss: 11.8839 - y1_output_loss: 4.5122 - y2_output_loss: 7.3736 - y1_output_root_mean_squared_error: 2.1281 - y2_output_root_mean_squared_error: 2.7120 - val_loss: 20.7947 - val_y1_output_loss: 7.5689 - val_y2_output_loss: 13.5958 - val_y1_output_root_mean_squared_error: 2.7095 - val_y2_output_root_mean_squared_error: 3.6679
# Epoch 30/500
# 614/614 [==============================] - 0s 130us/sample - loss: 11.9971 - y1_output_loss: 4.1578 - y2_output_loss: 7.9138 - y1_output_root_mean_squared_error: 2.0270 - y2_output_root_mean_squared_error: 2.8086 - val_loss: 19.2858 - val_y1_output_loss: 7.3554 - val_y2_output_loss: 11.7271 - val_y1_output_root_mean_squared_error: 2.6995 - val_y2_output_root_mean_squared_error: 3.4639
# Epoch 31/500
# 614/614 [==============================] - 0s 125us/sample - loss: 12.1756 - y1_output_loss: 4.2456 - y2_output_loss: 7.8489 - y1_output_root_mean_squared_error: 2.0640 - y2_output_root_mean_squared_error: 2.8135 - val_loss: 13.2286 - val_y1_output_loss: 5.0918 - val_y2_output_loss: 7.9452 - val_y1_output_root_mean_squared_error: 2.2438 - val_y2_output_root_mean_squared_error: 2.8625
# Epoch 32/500
# 614/614 [==============================] - 0s 137us/sample - loss: 13.8538 - y1_output_loss: 4.5384 - y2_output_loss: 9.2368 - y1_output_root_mean_squared_error: 2.1342 - y2_output_root_mean_squared_error: 3.0494 - val_loss: 10.7382 - val_y1_output_loss: 4.3593 - val_y2_output_loss: 6.2602 - val_y1_output_root_mean_squared_error: 2.0599 - val_y2_output_root_mean_squared_error: 2.5485
# Epoch 33/500
# 614/614 [==============================] - 0s 134us/sample - loss: 9.3917 - y1_output_loss: 3.3510 - y2_output_loss: 5.9634 - y1_output_root_mean_squared_error: 1.8384 - y2_output_root_mean_squared_error: 2.4519 - val_loss: 11.3005 - val_y1_output_loss: 5.1192 - val_y2_output_loss: 6.3376 - val_y1_output_root_mean_squared_error: 2.2239 - val_y2_output_root_mean_squared_error: 2.5209
# Epoch 34/500
# 614/614 [==============================] - 0s 131us/sample - loss: 12.3240 - y1_output_loss: 4.0768 - y2_output_loss: 8.1652 - y1_output_root_mean_squared_error: 2.0243 - y2_output_root_mean_squared_error: 2.8682 - val_loss: 16.3018 - val_y1_output_loss: 5.6305 - val_y2_output_loss: 10.3925 - val_y1_output_root_mean_squared_error: 2.3628 - val_y2_output_root_mean_squared_error: 3.2740
# Epoch 35/500
# 614/614 [==============================] - 0s 137us/sample - loss: 12.7300 - y1_output_loss: 3.8062 - y2_output_loss: 9.0238 - y1_output_root_mean_squared_error: 1.9359 - y2_output_root_mean_squared_error: 2.9971 - val_loss: 38.0050 - val_y1_output_loss: 12.1171 - val_y2_output_loss: 25.6816 - val_y1_output_root_mean_squared_error: 3.4681 - val_y2_output_root_mean_squared_error: 5.0968
# Epoch 36/500
# 614/614 [==============================] - 0s 134us/sample - loss: 9.5858 - y1_output_loss: 3.4385 - y2_output_loss: 6.1605 - y1_output_root_mean_squared_error: 1.8594 - y2_output_root_mean_squared_error: 2.4755 - val_loss: 35.0567 - val_y1_output_loss: 8.4913 - val_y2_output_loss: 27.5365 - val_y1_output_root_mean_squared_error: 2.8644 - val_y2_output_root_mean_squared_error: 5.1819
# Epoch 37/500
# 614/614 [==============================] - 0s 135us/sample - loss: 9.4155 - y1_output_loss: 3.0907 - y2_output_loss: 6.2484 - y1_output_root_mean_squared_error: 1.7662 - y2_output_root_mean_squared_error: 2.5092 - val_loss: 24.6139 - val_y1_output_loss: 7.2287 - val_y2_output_loss: 18.1329 - val_y1_output_root_mean_squared_error: 2.6421 - val_y2_output_root_mean_squared_error: 4.1992
# Epoch 38/500
# 614/614 [==============================] - 0s 130us/sample - loss: 10.6038 - y1_output_loss: 3.2812 - y2_output_loss: 7.4380 - y1_output_root_mean_squared_error: 1.8118 - y2_output_root_mean_squared_error: 2.7058 - val_loss: 27.1567 - val_y1_output_loss: 6.5105 - val_y2_output_loss: 21.5316 - val_y1_output_root_mean_squared_error: 2.5112 - val_y2_output_root_mean_squared_error: 4.5663
# Epoch 39/500
# 614/614 [==============================] - 0s 130us/sample - loss: 8.9540 - y1_output_loss: 2.9581 - y2_output_loss: 5.9938 - y1_output_root_mean_squared_error: 1.7238 - y2_output_root_mean_squared_error: 2.4460 - val_loss: 10.6390 - val_y1_output_loss: 4.4656 - val_y2_output_loss: 6.0351 - val_y1_output_root_mean_squared_error: 2.1093 - val_y2_output_root_mean_squared_error: 2.4879
# Epoch 40/500
# 614/614 [==============================] - 0s 128us/sample - loss: 8.5620 - y1_output_loss: 2.8395 - y2_output_loss: 5.6538 - y1_output_root_mean_squared_error: 1.6909 - y2_output_root_mean_squared_error: 2.3881 - val_loss: 8.2897 - val_y1_output_loss: 3.0878 - val_y2_output_loss: 5.1224 - val_y1_output_root_mean_squared_error: 1.7396 - val_y2_output_root_mean_squared_error: 2.2942
# Epoch 41/500
# 614/614 [==============================] - 0s 137us/sample - loss: 8.0431 - y1_output_loss: 2.8474 - y2_output_loss: 5.1377 - y1_output_root_mean_squared_error: 1.6911 - y2_output_root_mean_squared_error: 2.2767 - val_loss: 8.6590 - val_y1_output_loss: 3.3189 - val_y2_output_loss: 5.4599 - val_y1_output_root_mean_squared_error: 1.8048 - val_y2_output_root_mean_squared_error: 2.3242
# Epoch 42/500
# 614/614 [==============================] - 0s 125us/sample - loss: 8.7318 - y1_output_loss: 2.7326 - y2_output_loss: 5.9354 - y1_output_root_mean_squared_error: 1.6584 - y2_output_root_mean_squared_error: 2.4457 - val_loss: 10.1065 - val_y1_output_loss: 4.6946 - val_y2_output_loss: 5.4377 - val_y1_output_root_mean_squared_error: 2.1573 - val_y2_output_root_mean_squared_error: 2.3351
# Epoch 43/500
# 614/614 [==============================] - 0s 131us/sample - loss: 6.8197 - y1_output_loss: 2.2583 - y2_output_loss: 4.5246 - y1_output_root_mean_squared_error: 1.5063 - y2_output_root_mean_squared_error: 2.1332 - val_loss: 13.1182 - val_y1_output_loss: 3.9723 - val_y2_output_loss: 8.9605 - val_y1_output_root_mean_squared_error: 1.9936 - val_y2_output_root_mean_squared_error: 3.0238
# Epoch 44/500
# 614/614 [==============================] - 0s 131us/sample - loss: 7.6630 - y1_output_loss: 2.2177 - y2_output_loss: 5.3802 - y1_output_root_mean_squared_error: 1.4940 - y2_output_root_mean_squared_error: 2.3305 - val_loss: 7.1728 - val_y1_output_loss: 2.8502 - val_y2_output_loss: 4.3849 - val_y1_output_root_mean_squared_error: 1.6732 - val_y2_output_root_mean_squared_error: 2.0912
# Epoch 45/500
# 614/614 [==============================] - 0s 138us/sample - loss: 6.9638 - y1_output_loss: 2.1172 - y2_output_loss: 4.8405 - y1_output_root_mean_squared_error: 1.4600 - y2_output_root_mean_squared_error: 2.1983 - val_loss: 9.8510 - val_y1_output_loss: 3.1163 - val_y2_output_loss: 7.0360 - val_y1_output_root_mean_squared_error: 1.7320 - val_y2_output_root_mean_squared_error: 2.6175
# Epoch 46/500
# 614/614 [==============================] - 0s 136us/sample - loss: 7.8448 - y1_output_loss: 2.3547 - y2_output_loss: 5.5686 - y1_output_root_mean_squared_error: 1.5335 - y2_output_root_mean_squared_error: 2.3437 - val_loss: 20.6607 - val_y1_output_loss: 4.1809 - val_y2_output_loss: 16.2902 - val_y1_output_root_mean_squared_error: 2.0407 - val_y2_output_root_mean_squared_error: 4.0616
# Epoch 47/500
# 614/614 [==============================] - 0s 134us/sample - loss: 8.9836 - y1_output_loss: 2.6341 - y2_output_loss: 6.3238 - y1_output_root_mean_squared_error: 1.6205 - y2_output_root_mean_squared_error: 2.5214 - val_loss: 13.9068 - val_y1_output_loss: 4.7131 - val_y2_output_loss: 8.9742 - val_y1_output_root_mean_squared_error: 2.1733 - val_y2_output_root_mean_squared_error: 3.0304
# Epoch 48/500
# 614/614 [==============================] - 0s 124us/sample - loss: 8.8831 - y1_output_loss: 2.5124 - y2_output_loss: 6.3054 - y1_output_root_mean_squared_error: 1.5908 - y2_output_root_mean_squared_error: 2.5204 - val_loss: 7.9486 - val_y1_output_loss: 3.0749 - val_y2_output_loss: 4.7924 - val_y1_output_root_mean_squared_error: 1.7493 - val_y2_output_root_mean_squared_error: 2.2110
# Epoch 49/500
# 614/614 [==============================] - 0s 129us/sample - loss: 6.4405 - y1_output_loss: 2.1330 - y2_output_loss: 4.2872 - y1_output_root_mean_squared_error: 1.4542 - y2_output_root_mean_squared_error: 2.0799 - val_loss: 6.2644 - val_y1_output_loss: 2.4210 - val_y2_output_loss: 3.8941 - val_y1_output_root_mean_squared_error: 1.5318 - val_y2_output_root_mean_squared_error: 1.9794
# Epoch 50/500
# 614/614 [==============================] - 0s 130us/sample - loss: 7.5374 - y1_output_loss: 2.1358 - y2_output_loss: 5.4298 - y1_output_root_mean_squared_error: 1.4501 - y2_output_root_mean_squared_error: 2.3312 - val_loss: 11.3583 - val_y1_output_loss: 3.8596 - val_y2_output_loss: 7.3274 - val_y1_output_root_mean_squared_error: 1.9655 - val_y2_output_root_mean_squared_error: 2.7377
# Epoch 51/500
# 614/614 [==============================] - 0s 128us/sample - loss: 7.3724 - y1_output_loss: 2.2095 - y2_output_loss: 5.1259 - y1_output_root_mean_squared_error: 1.4868 - y2_output_root_mean_squared_error: 2.2720 - val_loss: 5.7464 - val_y1_output_loss: 2.0212 - val_y2_output_loss: 3.6966 - val_y1_output_root_mean_squared_error: 1.4200 - val_y2_output_root_mean_squared_error: 1.9314
# Epoch 52/500
# 614/614 [==============================] - 0s 122us/sample - loss: 8.2715 - y1_output_loss: 2.4124 - y2_output_loss: 5.7942 - y1_output_root_mean_squared_error: 1.5594 - y2_output_root_mean_squared_error: 2.4166 - val_loss: 5.9134 - val_y1_output_loss: 2.0887 - val_y2_output_loss: 3.8610 - val_y1_output_root_mean_squared_error: 1.4466 - val_y2_output_root_mean_squared_error: 1.9547
# Epoch 53/500
# 614/614 [==============================] - 0s 129us/sample - loss: 8.1253 - y1_output_loss: 2.3587 - y2_output_loss: 5.7547 - y1_output_root_mean_squared_error: 1.5418 - y2_output_root_mean_squared_error: 2.3975 - val_loss: 16.1794 - val_y1_output_loss: 4.4470 - val_y2_output_loss: 12.4437 - val_y1_output_root_mean_squared_error: 2.0653 - val_y2_output_root_mean_squared_error: 3.4517
# Epoch 54/500
# 614/614 [==============================] - 0s 131us/sample - loss: 6.6197 - y1_output_loss: 1.8680 - y2_output_loss: 4.7394 - y1_output_root_mean_squared_error: 1.3715 - y2_output_root_mean_squared_error: 2.1769 - val_loss: 5.6697 - val_y1_output_loss: 2.0248 - val_y2_output_loss: 3.6172 - val_y1_output_root_mean_squared_error: 1.4320 - val_y2_output_root_mean_squared_error: 1.9024
# Epoch 55/500
# 614/614 [==============================] - 0s 135us/sample - loss: 5.3957 - y1_output_loss: 1.6165 - y2_output_loss: 3.7915 - y1_output_root_mean_squared_error: 1.2592 - y2_output_root_mean_squared_error: 1.9520 - val_loss: 5.3258 - val_y1_output_loss: 1.7006 - val_y2_output_loss: 3.6218 - val_y1_output_root_mean_squared_error: 1.3099 - val_y2_output_root_mean_squared_error: 1.9000
# Epoch 56/500
# 614/614 [==============================] - 0s 129us/sample - loss: 4.8618 - y1_output_loss: 1.3272 - y2_output_loss: 3.4985 - y1_output_root_mean_squared_error: 1.1557 - y2_output_root_mean_squared_error: 1.8778 - val_loss: 6.4116 - val_y1_output_loss: 1.9371 - val_y2_output_loss: 4.4122 - val_y1_output_root_mean_squared_error: 1.3961 - val_y2_output_root_mean_squared_error: 2.1125
# Epoch 57/500
# 614/614 [==============================] - 0s 136us/sample - loss: 6.4820 - y1_output_loss: 1.6152 - y2_output_loss: 4.8412 - y1_output_root_mean_squared_error: 1.2729 - y2_output_root_mean_squared_error: 2.2049 - val_loss: 5.6548 - val_y1_output_loss: 2.0409 - val_y2_output_loss: 3.7206 - val_y1_output_root_mean_squared_error: 1.4249 - val_y2_output_root_mean_squared_error: 1.9038
# Epoch 58/500
# 614/614 [==============================] - 0s 131us/sample - loss: 6.2124 - y1_output_loss: 1.5755 - y2_output_loss: 4.5998 - y1_output_root_mean_squared_error: 1.2590 - y2_output_root_mean_squared_error: 2.1511 - val_loss: 7.3949 - val_y1_output_loss: 2.2694 - val_y2_output_loss: 5.3079 - val_y1_output_root_mean_squared_error: 1.5061 - val_y2_output_root_mean_squared_error: 2.2642
# Epoch 59/500
# 614/614 [==============================] - 0s 130us/sample - loss: 6.3659 - y1_output_loss: 1.6515 - y2_output_loss: 4.6895 - y1_output_root_mean_squared_error: 1.2824 - y2_output_root_mean_squared_error: 2.1729 - val_loss: 5.0605 - val_y1_output_loss: 1.5499 - val_y2_output_loss: 3.5189 - val_y1_output_root_mean_squared_error: 1.2309 - val_y2_output_root_mean_squared_error: 1.8829
# Epoch 60/500
# 614/614 [==============================] - 0s 129us/sample - loss: 4.7284 - y1_output_loss: 1.2469 - y2_output_loss: 3.4632 - y1_output_root_mean_squared_error: 1.1157 - y2_output_root_mean_squared_error: 1.8664 - val_loss: 6.1557 - val_y1_output_loss: 1.3709 - val_y2_output_loss: 4.7429 - val_y1_output_root_mean_squared_error: 1.1739 - val_y2_output_root_mean_squared_error: 2.1858
# Epoch 61/500
# 614/614 [==============================] - 0s 127us/sample - loss: 6.2944 - y1_output_loss: 1.5883 - y2_output_loss: 4.7070 - y1_output_root_mean_squared_error: 1.2557 - y2_output_root_mean_squared_error: 2.1720 - val_loss: 5.1201 - val_y1_output_loss: 1.3807 - val_y2_output_loss: 3.7212 - val_y1_output_root_mean_squared_error: 1.1810 - val_y2_output_root_mean_squared_error: 1.9301
# Epoch 62/500
# 614/614 [==============================] - 0s 128us/sample - loss: 4.2155 - y1_output_loss: 1.1490 - y2_output_loss: 3.0641 - y1_output_root_mean_squared_error: 1.0767 - y2_output_root_mean_squared_error: 1.7482 - val_loss: 7.7891 - val_y1_output_loss: 2.4958 - val_y2_output_loss: 5.5066 - val_y1_output_root_mean_squared_error: 1.5711 - val_y2_output_root_mean_squared_error: 2.3067
# Epoch 63/500
# 614/614 [==============================] - 0s 123us/sample - loss: 4.5209 - y1_output_loss: 1.2031 - y2_output_loss: 3.3253 - y1_output_root_mean_squared_error: 1.0979 - y2_output_root_mean_squared_error: 1.8209 - val_loss: 8.7639 - val_y1_output_loss: 2.7778 - val_y2_output_loss: 6.2104 - val_y1_output_root_mean_squared_error: 1.6548 - val_y2_output_root_mean_squared_error: 2.4547
# Epoch 64/500
# 614/614 [==============================] - 0s 136us/sample - loss: 4.9818 - y1_output_loss: 1.2694 - y2_output_loss: 3.7224 - y1_output_root_mean_squared_error: 1.1295 - y2_output_root_mean_squared_error: 1.9251 - val_loss: 12.7028 - val_y1_output_loss: 4.4892 - val_y2_output_loss: 7.9397 - val_y1_output_root_mean_squared_error: 2.1437 - val_y2_output_root_mean_squared_error: 2.8473
# Epoch 65/500
# 614/614 [==============================] - 0s 134us/sample - loss: 7.5280 - y1_output_loss: 1.9441 - y2_output_loss: 5.5187 - y1_output_root_mean_squared_error: 1.4003 - y2_output_root_mean_squared_error: 2.3595 - val_loss: 5.5096 - val_y1_output_loss: 1.5526 - val_y2_output_loss: 3.9798 - val_y1_output_root_mean_squared_error: 1.2532 - val_y2_output_root_mean_squared_error: 1.9847
# Epoch 66/500
# 614/614 [==============================] - 0s 129us/sample - loss: 5.5550 - y1_output_loss: 1.4204 - y2_output_loss: 4.0880 - y1_output_root_mean_squared_error: 1.1973 - y2_output_root_mean_squared_error: 2.0302 - val_loss: 5.0194 - val_y1_output_loss: 1.7955 - val_y2_output_loss: 3.2967 - val_y1_output_root_mean_squared_error: 1.3406 - val_y2_output_root_mean_squared_error: 1.7951
# Epoch 67/500
# 614/614 [==============================] - 0s 128us/sample - loss: 4.2069 - y1_output_loss: 0.9543 - y2_output_loss: 3.2246 - y1_output_root_mean_squared_error: 0.9783 - y2_output_root_mean_squared_error: 1.8027 - val_loss: 5.4840 - val_y1_output_loss: 1.2240 - val_y2_output_loss: 4.2356 - val_y1_output_root_mean_squared_error: 1.1088 - val_y2_output_root_mean_squared_error: 2.0626
# Epoch 68/500
# 614/614 [==============================] - 0s 132us/sample - loss: 4.1642 - y1_output_loss: 1.1064 - y2_output_loss: 3.0498 - y1_output_root_mean_squared_error: 1.0532 - y2_output_root_mean_squared_error: 1.7479 - val_loss: 5.7530 - val_y1_output_loss: 1.8113 - val_y2_output_loss: 4.0789 - val_y1_output_root_mean_squared_error: 1.3369 - val_y2_output_root_mean_squared_error: 1.9914
# Epoch 69/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.3791 - y1_output_loss: 1.0174 - y2_output_loss: 3.4030 - y1_output_root_mean_squared_error: 0.9978 - y2_output_root_mean_squared_error: 1.8394 - val_loss: 10.0120 - val_y1_output_loss: 4.1239 - val_y2_output_loss: 5.9136 - val_y1_output_root_mean_squared_error: 2.0402 - val_y2_output_root_mean_squared_error: 2.4186
# Epoch 70/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.0874 - y1_output_loss: 1.0570 - y2_output_loss: 3.0662 - y1_output_root_mean_squared_error: 1.0248 - y2_output_root_mean_squared_error: 1.7428 - val_loss: 10.5207 - val_y1_output_loss: 4.4579 - val_y2_output_loss: 6.1069 - val_y1_output_root_mean_squared_error: 2.1288 - val_y2_output_root_mean_squared_error: 2.4472
# Epoch 71/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.6541 - y1_output_loss: 0.8484 - y2_output_loss: 2.7814 - y1_output_root_mean_squared_error: 0.9210 - y2_output_root_mean_squared_error: 1.6751 - val_loss: 5.7427 - val_y1_output_loss: 1.8656 - val_y2_output_loss: 3.9914 - val_y1_output_root_mean_squared_error: 1.3774 - val_y2_output_root_mean_squared_error: 1.9610
# Epoch 72/500
# 614/614 [==============================] - 0s 136us/sample - loss: 4.6952 - y1_output_loss: 1.2282 - y2_output_loss: 3.4608 - y1_output_root_mean_squared_error: 1.1004 - y2_output_root_mean_squared_error: 1.8666 - val_loss: 5.3069 - val_y1_output_loss: 1.2633 - val_y2_output_loss: 4.0599 - val_y1_output_root_mean_squared_error: 1.1295 - val_y2_output_root_mean_squared_error: 2.0078
# Epoch 73/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.6392 - y1_output_loss: 0.8063 - y2_output_loss: 2.8429 - y1_output_root_mean_squared_error: 0.8922 - y2_output_root_mean_squared_error: 1.6862 - val_loss: 6.2909 - val_y1_output_loss: 2.2730 - val_y2_output_loss: 4.0720 - val_y1_output_root_mean_squared_error: 1.5237 - val_y2_output_root_mean_squared_error: 1.9923
# Epoch 74/500
# 614/614 [==============================] - 0s 127us/sample - loss: 4.9142 - y1_output_loss: 1.0199 - y2_output_loss: 3.8508 - y1_output_root_mean_squared_error: 1.0134 - y2_output_root_mean_squared_error: 1.9716 - val_loss: 3.6297 - val_y1_output_loss: 0.9251 - val_y2_output_loss: 2.7379 - val_y1_output_root_mean_squared_error: 0.9703 - val_y2_output_root_mean_squared_error: 1.6396
# Epoch 75/500
# 614/614 [==============================] - 0s 140us/sample - loss: 4.3633 - y1_output_loss: 1.1095 - y2_output_loss: 3.2257 - y1_output_root_mean_squared_error: 1.0562 - y2_output_root_mean_squared_error: 1.8021 - val_loss: 7.4232 - val_y1_output_loss: 1.7949 - val_y2_output_loss: 5.8565 - val_y1_output_root_mean_squared_error: 1.3398 - val_y2_output_root_mean_squared_error: 2.3723
# Epoch 76/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.6119 - y1_output_loss: 0.8314 - y2_output_loss: 2.8051 - y1_output_root_mean_squared_error: 0.9033 - y2_output_root_mean_squared_error: 1.6721 - val_loss: 10.0999 - val_y1_output_loss: 3.1410 - val_y2_output_loss: 6.7865 - val_y1_output_root_mean_squared_error: 1.7907 - val_y2_output_root_mean_squared_error: 2.6255
# Epoch 77/500
# 614/614 [==============================] - 0s 130us/sample - loss: 4.1577 - y1_output_loss: 1.1129 - y2_output_loss: 3.0349 - y1_output_root_mean_squared_error: 1.0475 - y2_output_root_mean_squared_error: 1.7494 - val_loss: 3.6606 - val_y1_output_loss: 0.9972 - val_y2_output_loss: 2.7840 - val_y1_output_root_mean_squared_error: 1.0032 - val_y2_output_root_mean_squared_error: 1.6292
# Epoch 78/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.2043 - y1_output_loss: 0.7223 - y2_output_loss: 2.5831 - y1_output_root_mean_squared_error: 0.8419 - y2_output_root_mean_squared_error: 1.5797 - val_loss: 24.8220 - val_y1_output_loss: 6.0582 - val_y2_output_loss: 19.3496 - val_y1_output_root_mean_squared_error: 2.4522 - val_y2_output_root_mean_squared_error: 4.3369
# Epoch 79/500
# 614/614 [==============================] - 0s 131us/sample - loss: 4.9210 - y1_output_loss: 1.1398 - y2_output_loss: 3.7994 - y1_output_root_mean_squared_error: 1.0529 - y2_output_root_mean_squared_error: 1.9525 - val_loss: 5.1038 - val_y1_output_loss: 1.4044 - val_y2_output_loss: 3.7130 - val_y1_output_root_mean_squared_error: 1.1905 - val_y2_output_root_mean_squared_error: 1.9200
# Epoch 80/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.7389 - y1_output_loss: 0.8670 - y2_output_loss: 2.8705 - y1_output_root_mean_squared_error: 0.9203 - y2_output_root_mean_squared_error: 1.7006 - val_loss: 3.4249 - val_y1_output_loss: 0.9018 - val_y2_output_loss: 2.5941 - val_y1_output_root_mean_squared_error: 0.9582 - val_y2_output_root_mean_squared_error: 1.5833
# Epoch 81/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.4744 - y1_output_loss: 0.7520 - y2_output_loss: 2.7003 - y1_output_root_mean_squared_error: 0.8691 - y2_output_root_mean_squared_error: 1.6490 - val_loss: 3.3304 - val_y1_output_loss: 0.7456 - val_y2_output_loss: 2.6949 - val_y1_output_root_mean_squared_error: 0.8642 - val_y2_output_root_mean_squared_error: 1.6074
# Epoch 82/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.5369 - y1_output_loss: 0.7801 - y2_output_loss: 2.7355 - y1_output_root_mean_squared_error: 0.8872 - y2_output_root_mean_squared_error: 1.6582 - val_loss: 2.9359 - val_y1_output_loss: 0.6888 - val_y2_output_loss: 2.3389 - val_y1_output_root_mean_squared_error: 0.8377 - val_y2_output_root_mean_squared_error: 1.4947
# Epoch 83/500
# 614/614 [==============================] - 0s 129us/sample - loss: 4.0170 - y1_output_loss: 1.0618 - y2_output_loss: 2.9327 - y1_output_root_mean_squared_error: 1.0328 - y2_output_root_mean_squared_error: 1.7177 - val_loss: 4.5787 - val_y1_output_loss: 0.7819 - val_y2_output_loss: 3.8510 - val_y1_output_root_mean_squared_error: 0.8906 - val_y2_output_root_mean_squared_error: 1.9456
# Epoch 84/500
# 614/614 [==============================] - 0s 142us/sample - loss: 3.1262 - y1_output_loss: 0.6437 - y2_output_loss: 2.5127 - y1_output_root_mean_squared_error: 0.8029 - y2_output_root_mean_squared_error: 1.5753 - val_loss: 4.8524 - val_y1_output_loss: 1.0616 - val_y2_output_loss: 3.8184 - val_y1_output_root_mean_squared_error: 1.0335 - val_y2_output_root_mean_squared_error: 1.9453
# Epoch 85/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.5728 - y1_output_loss: 0.7951 - y2_output_loss: 2.8586 - y1_output_root_mean_squared_error: 0.8752 - y2_output_root_mean_squared_error: 1.6754 - val_loss: 29.4185 - val_y1_output_loss: 10.1934 - val_y2_output_loss: 19.2827 - val_y1_output_root_mean_squared_error: 3.2146 - val_y2_output_root_mean_squared_error: 4.3686
# Epoch 86/500
# 614/614 [==============================] - 0s 128us/sample - loss: 6.4192 - y1_output_loss: 1.8114 - y2_output_loss: 4.5721 - y1_output_root_mean_squared_error: 1.3520 - y2_output_root_mean_squared_error: 2.1427 - val_loss: 3.9896 - val_y1_output_loss: 0.7066 - val_y2_output_loss: 3.3004 - val_y1_output_root_mean_squared_error: 0.8500 - val_y2_output_root_mean_squared_error: 1.8075
# Epoch 87/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.5095 - y1_output_loss: 0.7094 - y2_output_loss: 2.8086 - y1_output_root_mean_squared_error: 0.8430 - y2_output_root_mean_squared_error: 1.6730 - val_loss: 7.5642 - val_y1_output_loss: 2.1448 - val_y2_output_loss: 5.3655 - val_y1_output_root_mean_squared_error: 1.4733 - val_y2_output_root_mean_squared_error: 2.3224
# Epoch 88/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.8070 - y1_output_loss: 0.6486 - y2_output_loss: 2.1623 - y1_output_root_mean_squared_error: 0.8066 - y2_output_root_mean_squared_error: 1.4685 - val_loss: 5.8394 - val_y1_output_loss: 0.9643 - val_y2_output_loss: 4.8784 - val_y1_output_root_mean_squared_error: 0.9933 - val_y2_output_root_mean_squared_error: 2.2029
# Epoch 89/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.9999 - y1_output_loss: 0.6510 - y2_output_loss: 2.3357 - y1_output_root_mean_squared_error: 0.8051 - y2_output_root_mean_squared_error: 1.5335 - val_loss: 4.7143 - val_y1_output_loss: 0.5981 - val_y2_output_loss: 4.1574 - val_y1_output_root_mean_squared_error: 0.7814 - val_y2_output_root_mean_squared_error: 2.0258
# Epoch 90/500
# 614/614 [==============================] - 0s 132us/sample - loss: 4.6404 - y1_output_loss: 1.0453 - y2_output_loss: 3.5569 - y1_output_root_mean_squared_error: 1.0258 - y2_output_root_mean_squared_error: 1.8943 - val_loss: 6.8928 - val_y1_output_loss: 2.3280 - val_y2_output_loss: 4.6438 - val_y1_output_root_mean_squared_error: 1.5436 - val_y2_output_root_mean_squared_error: 2.1237
# Epoch 91/500
# 614/614 [==============================] - 0s 129us/sample - loss: 3.6703 - y1_output_loss: 0.8992 - y2_output_loss: 2.7367 - y1_output_root_mean_squared_error: 0.9524 - y2_output_root_mean_squared_error: 1.6623 - val_loss: 2.8412 - val_y1_output_loss: 0.5817 - val_y2_output_loss: 2.3309 - val_y1_output_root_mean_squared_error: 0.7707 - val_y2_output_root_mean_squared_error: 1.4991
# Epoch 92/500
# 614/614 [==============================] - 0s 130us/sample - loss: 3.2923 - y1_output_loss: 0.7374 - y2_output_loss: 2.6878 - y1_output_root_mean_squared_error: 0.8251 - y2_output_root_mean_squared_error: 1.6160 - val_loss: 22.4864 - val_y1_output_loss: 9.0737 - val_y2_output_loss: 13.0577 - val_y1_output_root_mean_squared_error: 3.0601 - val_y2_output_root_mean_squared_error: 3.6225
# Epoch 93/500
# 614/614 [==============================] - 0s 131us/sample - loss: 5.7083 - y1_output_loss: 1.5569 - y2_output_loss: 4.1251 - y1_output_root_mean_squared_error: 1.2487 - y2_output_root_mean_squared_error: 2.0369 - val_loss: 3.5867 - val_y1_output_loss: 0.6692 - val_y2_output_loss: 2.9732 - val_y1_output_root_mean_squared_error: 0.8183 - val_y2_output_root_mean_squared_error: 1.7079
# Epoch 94/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.2537 - y1_output_loss: 0.7621 - y2_output_loss: 2.5322 - y1_output_root_mean_squared_error: 0.8735 - y2_output_root_mean_squared_error: 1.5782 - val_loss: 7.4408 - val_y1_output_loss: 0.6513 - val_y2_output_loss: 6.8436 - val_y1_output_root_mean_squared_error: 0.8045 - val_y2_output_root_mean_squared_error: 2.6065
# Epoch 95/500
# 614/614 [==============================] - 0s 135us/sample - loss: 4.5848 - y1_output_loss: 1.0627 - y2_output_loss: 3.5103 - y1_output_root_mean_squared_error: 1.0318 - y2_output_root_mean_squared_error: 1.8762 - val_loss: 3.7203 - val_y1_output_loss: 1.0922 - val_y2_output_loss: 2.7233 - val_y1_output_root_mean_squared_error: 1.0438 - val_y2_output_root_mean_squared_error: 1.6220
# Epoch 96/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.1194 - y1_output_loss: 0.6593 - y2_output_loss: 2.4582 - y1_output_root_mean_squared_error: 0.8110 - y2_output_root_mean_squared_error: 1.5689 - val_loss: 6.0666 - val_y1_output_loss: 1.3832 - val_y2_output_loss: 4.7436 - val_y1_output_root_mean_squared_error: 1.1967 - val_y2_output_root_mean_squared_error: 2.1528
# Epoch 97/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.5344 - y1_output_loss: 0.7507 - y2_output_loss: 2.7949 - y1_output_root_mean_squared_error: 0.8653 - y2_output_root_mean_squared_error: 1.6690 - val_loss: 2.8584 - val_y1_output_loss: 0.7033 - val_y2_output_loss: 2.1961 - val_y1_output_root_mean_squared_error: 0.8494 - val_y2_output_root_mean_squared_error: 1.4618
# Epoch 98/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.9675 - y1_output_loss: 0.6017 - y2_output_loss: 2.3839 - y1_output_root_mean_squared_error: 0.7759 - y2_output_root_mean_squared_error: 1.5380 - val_loss: 5.3780 - val_y1_output_loss: 1.4094 - val_y2_output_loss: 4.0382 - val_y1_output_root_mean_squared_error: 1.2063 - val_y2_output_root_mean_squared_error: 1.9806
# Epoch 99/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.1842 - y1_output_loss: 0.7296 - y2_output_loss: 2.4372 - y1_output_root_mean_squared_error: 0.8581 - y2_output_root_mean_squared_error: 1.5646 - val_loss: 2.8548 - val_y1_output_loss: 0.6355 - val_y2_output_loss: 2.3140 - val_y1_output_root_mean_squared_error: 0.8011 - val_y2_output_root_mean_squared_error: 1.4876
# Epoch 100/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.7903 - y1_output_loss: 0.6545 - y2_output_loss: 2.1860 - y1_output_root_mean_squared_error: 0.8101 - y2_output_root_mean_squared_error: 1.4608 - val_loss: 7.2848 - val_y1_output_loss: 1.5757 - val_y2_output_loss: 5.9142 - val_y1_output_root_mean_squared_error: 1.2636 - val_y2_output_root_mean_squared_error: 2.3850
# Epoch 101/500
# 614/614 [==============================] - 0s 138us/sample - loss: 3.6906 - y1_output_loss: 0.9351 - y2_output_loss: 2.8308 - y1_output_root_mean_squared_error: 0.9414 - y2_output_root_mean_squared_error: 1.6746 - val_loss: 19.4639 - val_y1_output_loss: 7.0603 - val_y2_output_loss: 11.9933 - val_y1_output_root_mean_squared_error: 2.6921 - val_y2_output_root_mean_squared_error: 3.4952
# Epoch 102/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.9281 - y1_output_loss: 0.6703 - y2_output_loss: 2.2507 - y1_output_root_mean_squared_error: 0.8202 - y2_output_root_mean_squared_error: 1.5018 - val_loss: 7.0518 - val_y1_output_loss: 2.1167 - val_y2_output_loss: 4.8155 - val_y1_output_root_mean_squared_error: 1.4743 - val_y2_output_root_mean_squared_error: 2.2087
# Epoch 103/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.6853 - y1_output_loss: 0.5961 - y2_output_loss: 2.0887 - y1_output_root_mean_squared_error: 0.7745 - y2_output_root_mean_squared_error: 1.4441 - val_loss: 3.1013 - val_y1_output_loss: 0.7539 - val_y2_output_loss: 2.3320 - val_y1_output_root_mean_squared_error: 0.8720 - val_y2_output_root_mean_squared_error: 1.5300
# Epoch 104/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.6532 - y1_output_loss: 0.5959 - y2_output_loss: 2.0524 - y1_output_root_mean_squared_error: 0.7682 - y2_output_root_mean_squared_error: 1.4363 - val_loss: 2.8964 - val_y1_output_loss: 0.7548 - val_y2_output_loss: 2.2083 - val_y1_output_root_mean_squared_error: 0.8684 - val_y2_output_root_mean_squared_error: 1.4636
# Epoch 105/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.9001 - y1_output_loss: 0.5438 - y2_output_loss: 2.3452 - y1_output_root_mean_squared_error: 0.7375 - y2_output_root_mean_squared_error: 1.5350 - val_loss: 3.8212 - val_y1_output_loss: 0.6061 - val_y2_output_loss: 3.3427 - val_y1_output_root_mean_squared_error: 0.7865 - val_y2_output_root_mean_squared_error: 1.7896
# Epoch 106/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.0250 - y1_output_loss: 0.6655 - y2_output_loss: 2.3462 - y1_output_root_mean_squared_error: 0.8171 - y2_output_root_mean_squared_error: 1.5354 - val_loss: 11.9899 - val_y1_output_loss: 4.6409 - val_y2_output_loss: 7.1481 - val_y1_output_root_mean_squared_error: 2.1938 - val_y2_output_root_mean_squared_error: 2.6790
# Epoch 107/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.3637 - y1_output_loss: 0.7526 - y2_output_loss: 2.6451 - y1_output_root_mean_squared_error: 0.8606 - y2_output_root_mean_squared_error: 1.6196 - val_loss: 18.0654 - val_y1_output_loss: 5.2006 - val_y2_output_loss: 12.7715 - val_y1_output_root_mean_squared_error: 2.3159 - val_y2_output_root_mean_squared_error: 3.5640
# Epoch 108/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.9565 - y1_output_loss: 0.5983 - y2_output_loss: 2.3308 - y1_output_root_mean_squared_error: 0.7768 - y2_output_root_mean_squared_error: 1.5340 - val_loss: 2.4976 - val_y1_output_loss: 0.7743 - val_y2_output_loss: 1.7437 - val_y1_output_root_mean_squared_error: 0.8858 - val_y2_output_root_mean_squared_error: 1.3088
# Epoch 109/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.2265 - y1_output_loss: 0.6693 - y2_output_loss: 2.5297 - y1_output_root_mean_squared_error: 0.8209 - y2_output_root_mean_squared_error: 1.5977 - val_loss: 3.2044 - val_y1_output_loss: 0.9412 - val_y2_output_loss: 2.3288 - val_y1_output_root_mean_squared_error: 0.9779 - val_y2_output_root_mean_squared_error: 1.4994
# Epoch 110/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.4495 - y1_output_loss: 0.7879 - y2_output_loss: 2.6312 - y1_output_root_mean_squared_error: 0.8909 - y2_output_root_mean_squared_error: 1.6297 - val_loss: 2.9306 - val_y1_output_loss: 0.5228 - val_y2_output_loss: 2.4481 - val_y1_output_root_mean_squared_error: 0.7248 - val_y2_output_root_mean_squared_error: 1.5509
# Epoch 111/500
# 614/614 [==============================] - 0s 143us/sample - loss: 3.1942 - y1_output_loss: 0.7787 - y2_output_loss: 2.3903 - y1_output_root_mean_squared_error: 0.8862 - y2_output_root_mean_squared_error: 1.5520 - val_loss: 2.7799 - val_y1_output_loss: 0.5960 - val_y2_output_loss: 2.2284 - val_y1_output_root_mean_squared_error: 0.7826 - val_y2_output_root_mean_squared_error: 1.4722
# Epoch 112/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.2307 - y1_output_loss: 0.7441 - y2_output_loss: 2.4699 - y1_output_root_mean_squared_error: 0.8642 - y2_output_root_mean_squared_error: 1.5760 - val_loss: 2.9988 - val_y1_output_loss: 0.9216 - val_y2_output_loss: 2.1357 - val_y1_output_root_mean_squared_error: 0.9687 - val_y2_output_root_mean_squared_error: 1.4354
# Epoch 113/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.5716 - y1_output_loss: 0.5410 - y2_output_loss: 2.0219 - y1_output_root_mean_squared_error: 0.7298 - y2_output_root_mean_squared_error: 1.4279 - val_loss: 2.9861 - val_y1_output_loss: 0.4801 - val_y2_output_loss: 2.5255 - val_y1_output_root_mean_squared_error: 0.6978 - val_y2_output_root_mean_squared_error: 1.5809
# Epoch 114/500
# 614/614 [==============================] - 0s 137us/sample - loss: 3.9969 - y1_output_loss: 0.9014 - y2_output_loss: 3.0612 - y1_output_root_mean_squared_error: 0.9534 - y2_output_root_mean_squared_error: 1.7572 - val_loss: 2.9276 - val_y1_output_loss: 0.7864 - val_y2_output_loss: 2.1920 - val_y1_output_root_mean_squared_error: 0.8987 - val_y2_output_root_mean_squared_error: 1.4560
# Epoch 115/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.0455 - y1_output_loss: 0.6304 - y2_output_loss: 2.3920 - y1_output_root_mean_squared_error: 0.7975 - y2_output_root_mean_squared_error: 1.5523 - val_loss: 2.4552 - val_y1_output_loss: 0.4892 - val_y2_output_loss: 2.0002 - val_y1_output_root_mean_squared_error: 0.7009 - val_y2_output_root_mean_squared_error: 1.4014
# Epoch 116/500
# 614/614 [==============================] - 0s 140us/sample - loss: 2.8083 - y1_output_loss: 0.6809 - y2_output_loss: 2.1306 - y1_output_root_mean_squared_error: 0.8217 - y2_output_root_mean_squared_error: 1.4605 - val_loss: 2.5781 - val_y1_output_loss: 0.5880 - val_y2_output_loss: 2.0399 - val_y1_output_root_mean_squared_error: 0.7789 - val_y2_output_root_mean_squared_error: 1.4041
# Epoch 117/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.9487 - y1_output_loss: 0.5227 - y2_output_loss: 2.4354 - y1_output_root_mean_squared_error: 0.7185 - y2_output_root_mean_squared_error: 1.5596 - val_loss: 2.1492 - val_y1_output_loss: 0.3808 - val_y2_output_loss: 1.8227 - val_y1_output_root_mean_squared_error: 0.6222 - val_y2_output_root_mean_squared_error: 1.3274
# Epoch 118/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.7537 - y1_output_loss: 0.4708 - y2_output_loss: 2.2737 - y1_output_root_mean_squared_error: 0.6865 - y2_output_root_mean_squared_error: 1.5108 - val_loss: 3.7106 - val_y1_output_loss: 0.5876 - val_y2_output_loss: 3.2048 - val_y1_output_root_mean_squared_error: 0.7770 - val_y2_output_root_mean_squared_error: 1.7626
# Epoch 119/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.5838 - y1_output_loss: 0.5224 - y2_output_loss: 2.0459 - y1_output_root_mean_squared_error: 0.7228 - y2_output_root_mean_squared_error: 1.4358 - val_loss: 2.3664 - val_y1_output_loss: 0.4707 - val_y2_output_loss: 1.9065 - val_y1_output_root_mean_squared_error: 0.6954 - val_y2_output_root_mean_squared_error: 1.3721
# Epoch 120/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.4649 - y1_output_loss: 0.5232 - y2_output_loss: 1.9797 - y1_output_root_mean_squared_error: 0.7192 - y2_output_root_mean_squared_error: 1.3956 - val_loss: 8.2793 - val_y1_output_loss: 2.4810 - val_y2_output_loss: 5.8329 - val_y1_output_root_mean_squared_error: 1.5874 - val_y2_output_root_mean_squared_error: 2.3999
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3883 - y1_output_loss: 0.1305 - y2_output_loss: 0.2551 - y1_output_root_mean_squared_error: 0.3623 - y2_output_root_mean_squared_error: 0.5070 - val_loss: 0.6038 - val_y1_output_loss: 0.2012 - val_y2_output_loss: 0.3895 - val_y1_output_root_mean_squared_error: 0.4528 - val_y2_output_root_mean_squared_error: 0.6315
# Epoch 462/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3671 - y1_output_loss: 0.1271 - y2_output_loss: 0.2409 - y1_output_root_mean_squared_error: 0.3530 - y2_output_root_mean_squared_error: 0.4925 - val_loss: 0.6913 - val_y1_output_loss: 0.2386 - val_y2_output_loss: 0.4368 - val_y1_output_root_mean_squared_error: 0.4925 - val_y2_output_root_mean_squared_error: 0.6699
# Epoch 463/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4115 - y1_output_loss: 0.1155 - y2_output_loss: 0.2943 - y1_output_root_mean_squared_error: 0.3395 - y2_output_root_mean_squared_error: 0.5443 - val_loss: 0.8758 - val_y1_output_loss: 0.2449 - val_y2_output_loss: 0.6204 - val_y1_output_root_mean_squared_error: 0.5010 - val_y2_output_root_mean_squared_error: 0.7905
# Epoch 464/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.5492 - y1_output_loss: 0.1319 - y2_output_loss: 0.4173 - y1_output_root_mean_squared_error: 0.3589 - y2_output_root_mean_squared_error: 0.6483 - val_loss: 1.3858 - val_y1_output_loss: 0.6511 - val_y2_output_loss: 0.7028 - val_y1_output_root_mean_squared_error: 0.8122 - val_y2_output_root_mean_squared_error: 0.8522
# Epoch 465/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.4380 - y1_output_loss: 0.1343 - y2_output_loss: 0.3023 - y1_output_root_mean_squared_error: 0.3665 - y2_output_root_mean_squared_error: 0.5511 - val_loss: 0.8155 - val_y1_output_loss: 0.2078 - val_y2_output_loss: 0.5954 - val_y1_output_root_mean_squared_error: 0.4592 - val_y2_output_root_mean_squared_error: 0.7776
# Epoch 466/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.4252 - y1_output_loss: 0.1235 - y2_output_loss: 0.3008 - y1_output_root_mean_squared_error: 0.3529 - y2_output_root_mean_squared_error: 0.5483 - val_loss: 0.6800 - val_y1_output_loss: 0.1931 - val_y2_output_loss: 0.4705 - val_y1_output_root_mean_squared_error: 0.4436 - val_y2_output_root_mean_squared_error: 0.6951
# Epoch 467/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3607 - y1_output_loss: 0.1107 - y2_output_loss: 0.2481 - y1_output_root_mean_squared_error: 0.3340 - y2_output_root_mean_squared_error: 0.4991 - val_loss: 0.8439 - val_y1_output_loss: 0.2185 - val_y2_output_loss: 0.6139 - val_y1_output_root_mean_squared_error: 0.4677 - val_y2_output_root_mean_squared_error: 0.7907
# Epoch 468/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3794 - y1_output_loss: 0.1170 - y2_output_loss: 0.2595 - y1_output_root_mean_squared_error: 0.3435 - y2_output_root_mean_squared_error: 0.5112 - val_loss: 0.6769 - val_y1_output_loss: 0.1947 - val_y2_output_loss: 0.4740 - val_y1_output_root_mean_squared_error: 0.4475 - val_y2_output_root_mean_squared_error: 0.6904
# Epoch 469/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3007 - y1_output_loss: 0.1022 - y2_output_loss: 0.2001 - y1_output_root_mean_squared_error: 0.3177 - y2_output_root_mean_squared_error: 0.4469 - val_loss: 0.6805 - val_y1_output_loss: 0.2665 - val_y2_output_loss: 0.3979 - val_y1_output_root_mean_squared_error: 0.5218 - val_y2_output_root_mean_squared_error: 0.6389
# Epoch 470/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.4262 - y1_output_loss: 0.1231 - y2_output_loss: 0.2996 - y1_output_root_mean_squared_error: 0.3521 - y2_output_root_mean_squared_error: 0.5498 - val_loss: 0.6379 - val_y1_output_loss: 0.1886 - val_y2_output_loss: 0.4355 - val_y1_output_root_mean_squared_error: 0.4358 - val_y2_output_root_mean_squared_error: 0.6693
# Epoch 471/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.4033 - y1_output_loss: 0.1218 - y2_output_loss: 0.2819 - y1_output_root_mean_squared_error: 0.3494 - y2_output_root_mean_squared_error: 0.5303 - val_loss: 0.6899 - val_y1_output_loss: 0.1867 - val_y2_output_loss: 0.4891 - val_y1_output_root_mean_squared_error: 0.4376 - val_y2_output_root_mean_squared_error: 0.7059
# Epoch 472/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3556 - y1_output_loss: 0.1118 - y2_output_loss: 0.2437 - y1_output_root_mean_squared_error: 0.3353 - y2_output_root_mean_squared_error: 0.4932 - val_loss: 0.6179 - val_y1_output_loss: 0.2120 - val_y2_output_loss: 0.3873 - val_y1_output_root_mean_squared_error: 0.4676 - val_y2_output_root_mean_squared_error: 0.6319
# Epoch 473/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.4606 - y1_output_loss: 0.1164 - y2_output_loss: 0.3457 - y1_output_root_mean_squared_error: 0.3414 - y2_output_root_mean_squared_error: 0.5866 - val_loss: 1.1039 - val_y1_output_loss: 0.3447 - val_y2_output_loss: 0.7312 - val_y1_output_root_mean_squared_error: 0.5941 - val_y2_output_root_mean_squared_error: 0.8666
# Epoch 474/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.3609 - y1_output_loss: 0.1077 - y2_output_loss: 0.2507 - y1_output_root_mean_squared_error: 0.3293 - y2_output_root_mean_squared_error: 0.5025 - val_loss: 0.7144 - val_y1_output_loss: 0.2297 - val_y2_output_loss: 0.4721 - val_y1_output_root_mean_squared_error: 0.4841 - val_y2_output_root_mean_squared_error: 0.6929
# Epoch 475/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.5342 - y1_output_loss: 0.1609 - y2_output_loss: 0.3721 - y1_output_root_mean_squared_error: 0.4021 - y2_output_root_mean_squared_error: 0.6103 - val_loss: 1.0505 - val_y1_output_loss: 0.2356 - val_y2_output_loss: 0.8127 - val_y1_output_root_mean_squared_error: 0.4894 - val_y2_output_root_mean_squared_error: 0.9006
# Epoch 476/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.4255 - y1_output_loss: 0.1194 - y2_output_loss: 0.3040 - y1_output_root_mean_squared_error: 0.3454 - y2_output_root_mean_squared_error: 0.5534 - val_loss: 0.7855 - val_y1_output_loss: 0.2571 - val_y2_output_loss: 0.5150 - val_y1_output_root_mean_squared_error: 0.5143 - val_y2_output_root_mean_squared_error: 0.7218
# Epoch 477/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.5049 - y1_output_loss: 0.1284 - y2_output_loss: 0.3725 - y1_output_root_mean_squared_error: 0.3592 - y2_output_root_mean_squared_error: 0.6131 - val_loss: 0.6092 - val_y1_output_loss: 0.1941 - val_y2_output_loss: 0.4035 - val_y1_output_root_mean_squared_error: 0.4442 - val_y2_output_root_mean_squared_error: 0.6418
# Epoch 478/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.3698 - y1_output_loss: 0.1069 - y2_output_loss: 0.2607 - y1_output_root_mean_squared_error: 0.3274 - y2_output_root_mean_squared_error: 0.5124 - val_loss: 0.7107 - val_y1_output_loss: 0.1977 - val_y2_output_loss: 0.5026 - val_y1_output_root_mean_squared_error: 0.4458 - val_y2_output_root_mean_squared_error: 0.7155
# Epoch 479/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3557 - y1_output_loss: 0.1228 - y2_output_loss: 0.2308 - y1_output_root_mean_squared_error: 0.3511 - y2_output_root_mean_squared_error: 0.4821 - val_loss: 0.6457 - val_y1_output_loss: 0.1986 - val_y2_output_loss: 0.4338 - val_y1_output_root_mean_squared_error: 0.4511 - val_y2_output_root_mean_squared_error: 0.6650
# Epoch 480/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.3800 - y1_output_loss: 0.1213 - y2_output_loss: 0.2614 - y1_output_root_mean_squared_error: 0.3490 - y2_output_root_mean_squared_error: 0.5081 - val_loss: 1.3434 - val_y1_output_loss: 0.2942 - val_y2_output_loss: 1.0613 - val_y1_output_root_mean_squared_error: 0.5504 - val_y2_output_root_mean_squared_error: 1.0200
# Epoch 481/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3501 - y1_output_loss: 0.1206 - y2_output_loss: 0.2385 - y1_output_root_mean_squared_error: 0.3414 - y2_output_root_mean_squared_error: 0.4833 - val_loss: 2.6467 - val_y1_output_loss: 0.5337 - val_y2_output_loss: 2.1467 - val_y1_output_root_mean_squared_error: 0.7371 - val_y2_output_root_mean_squared_error: 1.4503
# Epoch 482/500
# 614/614 [==============================] - 0s 139us/sample - loss: 0.3932 - y1_output_loss: 0.1238 - y2_output_loss: 0.2756 - y1_output_root_mean_squared_error: 0.3476 - y2_output_root_mean_squared_error: 0.5219 - val_loss: 1.2804 - val_y1_output_loss: 0.3611 - val_y2_output_loss: 0.9159 - val_y1_output_root_mean_squared_error: 0.6053 - val_y2_output_root_mean_squared_error: 0.9560
# Epoch 483/500
# 614/614 [==============================] - 0s 135us/sample - loss: 0.3747 - y1_output_loss: 0.1167 - y2_output_loss: 0.2548 - y1_output_root_mean_squared_error: 0.3428 - y2_output_root_mean_squared_error: 0.5071 - val_loss: 0.6180 - val_y1_output_loss: 0.2036 - val_y2_output_loss: 0.3970 - val_y1_output_root_mean_squared_error: 0.4559 - val_y2_output_root_mean_squared_error: 0.6404
# Epoch 484/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3318 - y1_output_loss: 0.1026 - y2_output_loss: 0.2266 - y1_output_root_mean_squared_error: 0.3214 - y2_output_root_mean_squared_error: 0.4780 - val_loss: 0.8950 - val_y1_output_loss: 0.1901 - val_y2_output_loss: 0.6905 - val_y1_output_root_mean_squared_error: 0.4359 - val_y2_output_root_mean_squared_error: 0.8396
# Epoch 485/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3213 - y1_output_loss: 0.1024 - y2_output_loss: 0.2188 - y1_output_root_mean_squared_error: 0.3215 - y2_output_root_mean_squared_error: 0.4668 - val_loss: 1.0354 - val_y1_output_loss: 0.2415 - val_y2_output_loss: 0.7951 - val_y1_output_root_mean_squared_error: 0.4879 - val_y2_output_root_mean_squared_error: 0.8929
# Epoch 486/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3450 - y1_output_loss: 0.1027 - y2_output_loss: 0.2438 - y1_output_root_mean_squared_error: 0.3212 - y2_output_root_mean_squared_error: 0.4918 - val_loss: 1.1700 - val_y1_output_loss: 0.2049 - val_y2_output_loss: 0.9450 - val_y1_output_root_mean_squared_error: 0.4541 - val_y2_output_root_mean_squared_error: 0.9817
# Epoch 487/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.3837 - y1_output_loss: 0.1183 - y2_output_loss: 0.2663 - y1_output_root_mean_squared_error: 0.3439 - y2_output_root_mean_squared_error: 0.5152 - val_loss: 1.0335 - val_y1_output_loss: 0.2442 - val_y2_output_loss: 0.7856 - val_y1_output_root_mean_squared_error: 0.4914 - val_y2_output_root_mean_squared_error: 0.8900
# Epoch 488/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.4148 - y1_output_loss: 0.1405 - y2_output_loss: 0.2718 - y1_output_root_mean_squared_error: 0.3761 - y2_output_root_mean_squared_error: 0.5229 - val_loss: 0.7006 - val_y1_output_loss: 0.2572 - val_y2_output_loss: 0.4252 - val_y1_output_root_mean_squared_error: 0.5150 - val_y2_output_root_mean_squared_error: 0.6598
# Epoch 489/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3976 - y1_output_loss: 0.1198 - y2_output_loss: 0.2778 - y1_output_root_mean_squared_error: 0.3473 - y2_output_root_mean_squared_error: 0.5263 - val_loss: 0.7857 - val_y1_output_loss: 0.2165 - val_y2_output_loss: 0.5638 - val_y1_output_root_mean_squared_error: 0.4718 - val_y2_output_root_mean_squared_error: 0.7504
# Epoch 490/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.4164 - y1_output_loss: 0.1430 - y2_output_loss: 0.2713 - y1_output_root_mean_squared_error: 0.3793 - y2_output_root_mean_squared_error: 0.5221 - val_loss: 0.7275 - val_y1_output_loss: 0.1940 - val_y2_output_loss: 0.5211 - val_y1_output_root_mean_squared_error: 0.4418 - val_y2_output_root_mean_squared_error: 0.7296
# Epoch 491/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3428 - y1_output_loss: 0.1074 - y2_output_loss: 0.2372 - y1_output_root_mean_squared_error: 0.3292 - y2_output_root_mean_squared_error: 0.4842 - val_loss: 0.6989 - val_y1_output_loss: 0.1877 - val_y2_output_loss: 0.5004 - val_y1_output_root_mean_squared_error: 0.4347 - val_y2_output_root_mean_squared_error: 0.7141
# Epoch 492/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3132 - y1_output_loss: 0.1048 - y2_output_loss: 0.2105 - y1_output_root_mean_squared_error: 0.3242 - y2_output_root_mean_squared_error: 0.4562 - val_loss: 1.0113 - val_y1_output_loss: 0.3219 - val_y2_output_loss: 0.6837 - val_y1_output_root_mean_squared_error: 0.5733 - val_y2_output_root_mean_squared_error: 0.8262
# Epoch 493/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.6435 - y1_output_loss: 0.1817 - y2_output_loss: 0.4582 - y1_output_root_mean_squared_error: 0.4263 - y2_output_root_mean_squared_error: 0.6796 - val_loss: 0.8863 - val_y1_output_loss: 0.3081 - val_y2_output_loss: 0.5532 - val_y1_output_root_mean_squared_error: 0.5602 - val_y2_output_root_mean_squared_error: 0.7566
# Epoch 494/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.3667 - y1_output_loss: 0.1048 - y2_output_loss: 0.2616 - y1_output_root_mean_squared_error: 0.3225 - y2_output_root_mean_squared_error: 0.5126 - val_loss: 0.6452 - val_y1_output_loss: 0.1837 - val_y2_output_loss: 0.4488 - val_y1_output_root_mean_squared_error: 0.4273 - val_y2_output_root_mean_squared_error: 0.6802
# Epoch 495/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3592 - y1_output_loss: 0.1153 - y2_output_loss: 0.2414 - y1_output_root_mean_squared_error: 0.3410 - y2_output_root_mean_squared_error: 0.4929 - val_loss: 0.6631 - val_y1_output_loss: 0.1825 - val_y2_output_loss: 0.4640 - val_y1_output_root_mean_squared_error: 0.4286 - val_y2_output_root_mean_squared_error: 0.6923
# Epoch 496/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3693 - y1_output_loss: 0.1113 - y2_output_loss: 0.2568 - y1_output_root_mean_squared_error: 0.3348 - y2_output_root_mean_squared_error: 0.5071 - val_loss: 0.7110 - val_y1_output_loss: 0.1942 - val_y2_output_loss: 0.5102 - val_y1_output_root_mean_squared_error: 0.4418 - val_y2_output_root_mean_squared_error: 0.7182
# Epoch 497/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3545 - y1_output_loss: 0.1149 - y2_output_loss: 0.2458 - y1_output_root_mean_squared_error: 0.3394 - y2_output_root_mean_squared_error: 0.4892 - val_loss: 2.5059 - val_y1_output_loss: 0.3219 - val_y2_output_loss: 2.2336 - val_y1_output_root_mean_squared_error: 0.5743 - val_y2_output_root_mean_squared_error: 1.4752
# Epoch 498/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.4421 - y1_output_loss: 0.1204 - y2_output_loss: 0.3190 - y1_output_root_mean_squared_error: 0.3484 - y2_output_root_mean_squared_error: 0.5663 - val_loss: 0.7011 - val_y1_output_loss: 0.1836 - val_y2_output_loss: 0.5112 - val_y1_output_root_mean_squared_error: 0.4305 - val_y2_output_root_mean_squared_error: 0.7182
# Epoch 499/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3005 - y1_output_loss: 0.1014 - y2_output_loss: 0.1976 - y1_output_root_mean_squared_error: 0.3187 - y2_output_root_mean_squared_error: 0.4460 - val_loss: 0.6615 - val_y1_output_loss: 0.2141 - val_y2_output_loss: 0.4370 - val_y1_output_root_mean_squared_error: 0.4659 - val_y2_output_root_mean_squared_error: 0.6666
# Epoch 500/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3185 - y1_output_loss: 0.1032 - y2_output_loss: 0.2156 - y1_output_root_mean_squared_error: 0.3194 - y2_output_root_mean_squared_error: 0.4653 - val_loss: 1.0911 - val_y1_output_loss: 0.3700 - val_y2_output_loss: 0.7107 - val_y1_output_root_mean_squared_error: 0.6053 - val_y2_output_root_mean_squared_error: 0.8513

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 31us/sample - loss: 1.0911 - y1_output_loss: 0.3660 - y2_output_loss: 0.7297 - y1_output_root_mean_squared_error: 0.6053 - y2_output_root_mean_squared_error: 0.8513
# Loss = 1.0911179595179372, Y1_loss = 0.3659709393978119, Y1_mse = 0.6053137183189392, Y2_loss = 0.7296714782714844, Y2_mse = 0.8513008952140808

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'y1_output_loss', 'y2_output_loss', 'y1_output_root_mean_squared_error', 'y2_output_root_mean_squared_error', 'val_loss', 'val_y1_output_loss', 'val_y2_output_loss', 'val_y1_output_root_mean_squared_error', 'val_y2_output_root_mean_squared_error'])

# %%
model.metrics_names
# Out:
# ['loss',
#  'y1_output_loss',
#  'y2_output_loss',
#  'y1_output_root_mean_squared_error',
#  'y2_output_root_mean_squared_error']

# %%
plt.plot([-100, 100], [-100, 100])
